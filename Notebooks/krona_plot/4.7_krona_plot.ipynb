# %% [markdown]
# # Create Kronaplot for all viruses across all cells grouped by animal and timepoint:

# %%
bp = "PRJNA665227"
fastq_folder = f"/home/laura/projects/virus-watch-data/{bp}"
u_tax = f"/home/laura/projects/virus-watch-data/virus_ref/u_tax_nodup_clu.csv"

# %%
import anndata
import pandas as pd
import numpy as np

def nd(arr):
    """
    Function to transform numpy matrix to nd array.
    """
    return np.asarray(arr).reshape(-1)

# Path to Krona tool
ktImportText = "/home/laura/bin/ktImportText"

# %% [markdown]
# ___
# # Load data

# %%
palmdb_adata = anndata.read(f"{fastq_folder}/host_flag/virus_cdna_dna_masked_meta.h5ad")
palmdb_adata
# Out:
# /home/laura/anaconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1828: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# AnnData object with n_obs × n_vars = 225898 × 11176
#     obs: 'sample_barcode', 'srr', 'Run', 'donor_animal', 'Experiment', 'mdck_spike_in', 'hours_post_innoculation', 'day_post_infection', 'dpi', 'dpi_accessions', 'dpi_clean', 'leiden', 'celltype_clusters', 'celltype', 'species', 'dpi_clean_merged'
#     var: 'v_type'

# %% [markdown]
# Only keep macaque viruses and cells that passed QC:

# %%
palmdb_adata = palmdb_adata[palmdb_adata.obs["celltype"].notnull(), palmdb_adata.var["v_type"] != "below_threshold"].copy()
palmdb_adata
# Out:
# AnnData object with n_obs × n_vars = 195399 × 80
#     obs: 'sample_barcode', 'srr', 'Run', 'donor_animal', 'Experiment', 'mdck_spike_in', 'hours_post_innoculation', 'day_post_infection', 'dpi', 'dpi_accessions', 'dpi_clean', 'leiden', 'celltype_clusters', 'celltype', 'species', 'dpi_clean_merged'
#     var: 'v_type'

# %% [markdown]
# Load ID to phylogeny mapping:

# %%
id2tax = pd.read_csv(u_tax)

# Drop columns not needed here and drop taxonomyduplicates
id2tax = id2tax.drop("ID", axis=1).drop("strandedness", axis=1)
id2tax = id2tax.drop_duplicates()

id2tax
# Out:
#          rep_ID           phylum            class            order  \
# 0            u1     Pisuviricota  Pisoniviricetes      Nidovirales
# 409         u10  Negarnaviricota   Monjiviricetes  Mononegavirales
# 475        u100  Kitrinoviricota   Flasuviricetes  Amarillovirales
# 590        u102  Kitrinoviricota    Alsuviricetes    Hepelivirales
# 909        u113  Negarnaviricota   Monjiviricetes  Mononegavirales
# ...         ...              ...              ...              ...
# 296556  u296608                .                .                .
# 296557  u296609                .                .                .
# 296558  u296613                .                .                .
# 296559  u296616                .                .                .
# 296560  u296623                .                .                .
#
#                  family            genus  \
# 0         Coronaviridae  Betacoronavirus
# 409         Filoviridae       Ebolavirus
# 475        Flaviviridae       Flavivirus
# 590         Hepeviridae   Orthohepevirus
# 909     Paramyxoviridae    Morbillivirus
# ...                 ...              ...
# 296556                .                .
# 296557                .                .
# 296558                .                .
# 296559                .                .
# 296560                .                .
#
#                                                   species
# 0       Severe acute respiratory syndrome-related coro...
# 409                                      Zaire ebolavirus
# 475                                       West Nile virus
# 590                                      Orthohepevirus A
# 909                                 Measles morbillivirus
# ...                                                   ...
# 296556                                                  .
# 296557                                                  .
# 296558                                                  .
# 296559                                                  .
# 296560                                                  .
#
# [99228 rows x 7 columns]

# %% [markdown]
# ___
# # Generate Krona html

# %%
# %%time
master = pd.DataFrame()
for idx, timepoint in enumerate(palmdb_adata.obs["dpi_clean_merged"].unique()):
    for animal_id in palmdb_adata.obs[palmdb_adata.obs["dpi_clean_merged"] == timepoint]["donor_animal"].unique():
        adata_temp = palmdb_adata[(palmdb_adata.obs["dpi_clean_merged"] == timepoint) & (palmdb_adata.obs["donor_animal"] == animal_id), :]

        # Add total number of counts (across all cells) for each virus ID to phylogeny data temp
        virus_ids = adata_temp.var.index.values
        total_counts = nd(adata_temp.X.sum(axis=0))
        total_count_dict = {virus_ids[i]: total_counts[i] for i in range(len(virus_ids))}

        phylogeny_data_temp = id2tax.copy()
        phylogeny_data_temp['total_count'] = phylogeny_data_temp['rep_ID'].map(total_count_dict)
        
        # Drop viruses not in filter list
        phylogeny_data_temp = phylogeny_data_temp.dropna()

        # Remove non-relevent columns and change order of columns  
        phylogeny_data_temp = phylogeny_data_temp[["total_count", "phylum", "class", "order", "family", "genus", "species", "rep_ID"]]

        # Replace dots with NaN
        phylogeny_data_temp = phylogeny_data_temp.replace(".", np.nan)

        # Add column with timepoint
        phylogeny_data_temp["timepoint"] = timepoint

        # Add column with animal id
        phylogeny_data_temp["animal_id"] = animal_id

        # Append to master dataframe
        if idx == 0:
            master = phylogeny_data_temp.copy()
        else:
            master = pd.concat([master, phylogeny_data_temp])

# Save counts + taxnomomies data to txt
master.to_csv(f'krona.txt', sep ='\t', header=None, index=False)

# Generate Krona plot
krona_out = "krona.html"
# !$ktImportText krona.txt -o $krona_out -n "Virus-positive cells"
# Out:
# Writing krona.html...
# CPU times: user 4.05 s, sys: 0 ns, total: 4.05 s
# Wall time: 4.69 s

# %%
# !ls -lh
# Out:
# total 149M
# -rw-rw-r-- 1 laura laura  160K Apr  3  2023 1_data_download.ipynb
# -rw-rw-r-- 1 laura laura   34K Oct 18 20:34 2.1_align_HostGenomeTranscriptome_noGTF.ipynb
# -rw-rw-r-- 1 laura laura  154K Oct 28 19:18 2.1_align_remove_reads_bus_AlignSRRindividually.ipynb
# -rw-rw-r-- 1 laura laura  287K Oct 31 07:34 2.1_align_remove_reads_bus+d-list.ipynb
# -rw-rw-r-- 1 laura laura  251K Oct 28 13:35 2.1_align_remove_reads_bus.ipynb
# -rw-rw-r-- 1 laura laura   26K Oct 27 14:43 2.1_align_remove_reads_bus_testing.ipynb
# -rw-rw-r-- 1 laura laura   50K Oct 18 07:59 2.1_align_virus_host_transcriptome+genome+ambigious.ipynb
# -rw-rw-r-- 1 laura laura   54K Oct 16 11:15 2.1_align_virus_host_transcriptome+genome_CheckEachKmer.ipynb
# -rw-rw-r-- 1 laura laura   11K Oct 18 16:45 2.1_align_virus_host_transcriptome+genome_DlistAll.ipynb
# -rw-rw-r-- 1 laura laura   43K Oct  7 11:42 2.1_align_virus_host_transcriptome+genome.ipynb
# -rw-rw-r-- 1 laura laura   48K Oct  4 16:37 2.1_align_virus_host_transcriptome.ipynb
# -rw-rw-r-- 1 laura laura   49K Oct 11 23:47 2.1_align_virus_no-host-mask.ipynb
# -rw-rw-r-- 1 laura laura   48K Oct  3 12:12 2.1_align_virus_overhang3.ipynb
# -rw-rw-r-- 1 laura laura   37K Aug 25 19:30 2.1_align_virus_to_bwa_host_removed.ipynb
# -rw-rw-r-- 1 laura laura   17K Oct 20 15:36 2.2_align_alphacoronavirus.ipynb
# -rw-rw-r-- 1 laura laura   42K Jul 17 00:47 2.2_align_dengue.ipynb
# -rw-rw-r-- 1 laura laura   40K Oct  8 23:07 2.2_align_enterovirusC.ipynb
# -rw-rw-r-- 1 laura laura   11K Aug 11 14:12 2.2_align_macdisease_viruses.ipynb
# -rw-rw-r-- 1 laura laura   45K Oct 19 16:01 2.2_align_OV_sars_cov2.ipynb
# -rw-rw-r-- 1 laura laura   46K Jul 14 02:30 2.2_align_SARSCoV.ipynb
# -rw-rw-r-- 1 laura laura   11K Aug  7 13:09 2.3_align_host_against_virus.ipynb
# -rw-rw-r-- 1 laura laura   88K Aug 15 18:00 2_align_host+canine+virus.ipynb
# -rw-rw-r-- 1 laura laura  931K Jul 15 16:28 3.1_host_QC.ipynb
# -rw-rw-r-- 1 laura laura  1.2M Jul 18 17:14 3.2_host_normalization_clustering.ipynb
# -rw-rw-r-- 1 laura laura  376K Jul 13 19:29 3.3_host_celltype_assignment.ipynb
# -rw-rw-r-- 1 laura laura  414K Oct 28 15:24 3.4_viral_QC_bwa.ipynb
# -rw-rw-r-- 1 laura laura  471K Oct 28 15:24 3.4_viral_QC_cdna+dna+amb.ipynb
# -rw-rw-r-- 1 laura laura  476K Oct 28 15:24 3.4_viral_QC_cdna+dna.ipynb
# -rw-rw-r-- 1 laura laura  501K Oct 28 15:24 3.4_viral_QC_cdna.ipynb
# -rw-rw-r-- 1 laura laura  476K Oct 28 15:24 3.4_viral_QC_CheckEachKmer.ipynb
# -rw-rw-r-- 1 laura laura  482K Oct 28 15:24 3.4_viral_QC.ipynb
# -rw-rw-r-- 1 laura laura  522K Oct 28 15:24 3.4_viral_QC_no-host-mask.ipynb
# -rw-rw-r-- 1 laura laura  651K Nov  6 16:07 3.4_viral_QC_remove-reads-bus+d-list.ipynb
# -rw-rw-r-- 1 laura laura  603K Oct 28 15:26 3.4_viral_QC_remove-reads-bus.ipynb
# -rw-rw-r-- 1 laura laura  728K Jul 24 16:39 3.5_host_celltype_fractions.ipynb
# -rw-rw-r-- 1 laura laura   15K Oct 31 10:17 3.6_bwa_vs_dlist.csv
# -rw-rw-r-- 1 laura laura  2.3M Nov  2 14:26 3.6_bwa_vs_dlist.ipynb
# -rw-rw-r-- 1 laura laura  2.5M Oct 19 16:07 3_OV_SARS_cov2_QC.ipynb
# -rw-rw-r-- 1 laura laura  586K Sep 19 03:05 4.1_qPCR_clinical_outcome_correlations_bwa.ipynb
# -rw-rw-r-- 1 laura laura  336K Oct 31 16:31 4.1_qPCR_clinical_outcome_correlations_cdna_dna_uncorrected.ipynb
# -rw-rw-r-- 1 laura laura  602K Sep 19 03:07 4.1_qPCR_clinical_outcome_correlations.ipynb
# -rw-rw-r-- 1 laura laura  1.3K Oct 31 18:13 4.2_fractions_vtype_per_tax_bus+d-list.csv
# -rw-rw-r-- 1 laura laura  1.2K Sep 19 03:50 4.2_fractions_vtype_per_tax_bwa.csv
# -rw-rw-r-- 1 laura laura  1.6K Sep 19 04:36 4.2_fractions_vtype_per_tax.csv
# -rw-rw-r-- 1 laura laura   299 Oct 31 18:16 4.2_ID2tax_top100_bus+d-list.csv
# -rw-rw-r-- 1 laura laura   368 Sep 20 05:07 4.2_ID2tax_top100_bwa.csv
# -rw-rw-r-- 1 laura laura   910 Oct  7 15:40 4.2_ID2tax_top100_cdna_dna.csv
# -rw-rw-r-- 1 laura laura  1.2K Sep 19 03:05 4.2_ID2tax_top100.csv
# -rw-rw-r-- 1 laura laura  3.2K Oct 31 18:17 4.2_ID2tax_top100_shared_bus+d-list.csv
# -rw-rw-r-- 1 laura laura  1.8K Sep 19 03:18 4.2_ID2tax_top100_shared_bwa.csv
# -rw-rw-r-- 1 laura laura  3.9K Sep 19 03:30 4.2_ID2tax_top100_shared.csv
# -rw-rw-r-- 1 laura laura  169K Aug 10 11:58 4.2_vir_fracs_celltype.csv
# -rw-rw-r-- 1 laura laura  173K Jul 15 14:05 4.2_vir_fracs_tp_animal_archive.csv
# -rw-rw-r-- 1 laura laura  3.2K Oct 31 18:12 4.2_vir_fracs_tp_animal_bus+d-list.csv
# -rw-rw-r-- 1 laura laura  3.9K Sep 20 05:07 4.2_vir_fracs_tp_animal_bwa.csv
# -rw-rw-r-- 1 laura laura   16K Oct  7 11:57 4.2_vir_fracs_tp_animal_cdna_dna.csv
# -rw-rw-r-- 1 laura laura   21K Sep 19 03:05 4.2_vir_fracs_tp_animal.csv
# -rw-rw-r-- 1 laura laura   47K Oct 31 18:13 4.2_vir_fracs_tp_animal_shared_bus+d-list.csv
# -rw-rw-r-- 1 laura laura   47K Oct 31 17:15 4.2_vir_fracs_tp_animal_shared_bwa.csv
# -rw-rw-r-- 1 laura laura   56K Sep 19 03:30 4.2_vir_fracs_tp_animal_shared.csv
# -rw-rw-r-- 1 laura laura  766K Nov  1 14:09 4.2_virus_fractions_bus+d-list.ipynb
# -rw-rw-r-- 1 laura laura  881K Sep 20 05:11 4.2_virus_fractions_bwa.ipynb
# -rw-rw-r-- 1 laura laura 1005K Oct  7 17:23 4.2_virus_fractions_cdna_dna.ipynb
# -rw-rw-r-- 1 laura laura  1.2M Sep 19 04:36 4.2_virus_fractions.ipynb
# -rw-rw-r-- 1 laura laura  1.4M Oct 31 20:38 4.3_virus_per_celltypes_bus+d-list.ipynb
# -rw-rw-r-- 1 laura laura  1.1M Sep 20 07:32 4.3_virus_per_celltypes_bwa.ipynb
# -rw-rw-r-- 1 laura laura  1.4M Sep 19 03:06 4.3_virus_per_celltypes.ipynb
# -rw-rw-r-- 1 laura laura  3.0M Oct 31 21:10 4.4_common_macaque_infections_bus+d-list.ipynb
# -rw-rw-r-- 1 laura laura  3.0M Sep 19 03:07 4.4_common_macaque_infections_bwa.ipynb
# -rw-rw-r-- 1 laura laura  3.0M Sep 19 03:09 4.4_common_macaque_infections.ipynb
# -rw-rw-r-- 1 laura laura  425K Aug  7 12:29 4.5_virus_correlations.ipynb
# -rw-rw-r-- 1 laura laura  2.0M Nov  2 16:30 4.6_virus_profiles_+_host_expression_bus+d-list.ipynb
# -rw-rw-r-- 1 laura laura  967K Sep 20 09:03 4.6_virus_profiles_+_host_expression_bwa.ipynb
# -rw-rw-r-- 1 laura laura  700K Sep 19 04:05 4.6_virus_profiles_+_host_expression.ipynb
# -rw-rw-r-- 1 laura laura   27K Nov  8 10:53 4.7_krona_plot.ipynb
# -rw-rw-r-- 1 laura laura  4.6M Sep 19 00:35 4.8_virus_l1_distances_bwa.ipynb
# -rw-rw-r-- 1 laura laura  4.6M Oct  7 18:04 4.8_virus_l1_distances_cdna_dna.ipynb
# -rw-rw-r-- 1 laura laura  4.6M Sep 19 03:10 4.8_virus_l1_distances.ipynb
# -rw-rw-r-- 1 laura laura  168K Aug  1 12:22 5.1_linear_models.ipynb
# -rw-rw-r-- 1 laura laura  1.2M Jul 26 15:55 5_linear_models.ipynb
# -rw-rw-r-- 1 laura laura  725K Sep 19 20:56 6_pca_bwa.ipynb
# -rw-rw-r-- 1 laura laura  612K Sep 19 20:52 6_pca.ipynb
# -rw-rw-r-- 1 laura laura  461K Sep 19 03:12 7_deseq2_bwa.ipynb
# -rw-rw-r-- 1 laura laura  623K Sep 19 03:13 7_deseq2.ipynb
# drwxrwxr-x 3 laura laura  4.0K Aug 11 13:04 archive
# drwxrwxr-x 2 laura laura  4.0K Oct 19 13:51 blast_results
# -rw-rw-r-- 1 laura laura   51K Oct 25 16:05 bowtie2_coronavirus_alignment.ipynb
# -rw-rw-r-- 1 laura laura   30K Oct 25 17:22 bowtie2_virus+host_doubles_alignment.ipynb
# -rw-rw-r-- 1 laura laura  2.1K Apr 27  2023 clinical_scores_fixid.tsv
# -rw-rw-r-- 1 laura laura  4.8K Oct 19 12:10 extract_reads.py
# drwxrwxr-x 3 laura laura   20K Nov  7 18:01 figures
# -rw-rw-r-- 1 laura laura  1.6M Nov  7 18:21 hv_l2_donor_time_gene_weights.ipynb
# -rw-rw-r-- 1 laura laura  137K Nov  6 15:25 hv_l2_donor_time_gene_weights.xlsx
# -rw-rw-r-- 1 laura laura  472K Nov  8 10:54 krona.html
# -rw-rw-r-- 1 laura laura  133K Nov  8 10:54 krona.txt
# -rw-rw-r-- 1 laura laura   904 Jul  3 12:19 marker_list.csv
# -rw-rw-r-- 1 laura laura  183K Jul 25 20:53 norm_multilinear_top20_dict_lasso_immune.pickle
# -rw-rw-r-- 1 laura laura  8.8M Jul 24 14:29 norm_multilinear_top20_dict.pickle
# -rw-rw-r-- 1 laura laura   129 Mar 22  2023 notes.txt
# -rw-rw-r-- 1 laura laura   74K Mar 10  2023 PRJNA665227_data.json
# -rw-rw-r-- 1 laura laura   24K Sep 19 06:47 pull_out_reads_all_archive.csv
# -rw-rw-r-- 1 laura laura   35K Oct  3 15:10 pull_out_reads_all_bwa.csv
# -rw-rw-r-- 1 laura laura   46K Oct 10 16:12 pull_out_reads_all_cdna_dna.csv
# -rw-rw-r-- 1 laura laura   68K Sep 29 17:15 pull_out_reads_all_new.csv
# -rw-rw-r-- 1 laura laura  891K Sep 20 03:26 pull_out_reads_archive.ipynb
# -rw-rw-r-- 1 laura laura   57K Oct 20 12:18 pull_out_reads_blast+_cdna_dna.csv
# -rw-rw-r-- 1 laura laura   46M Nov  6 16:46 pull_out_reads_BLAST_comparisons_archive.ipynb
# -rw-rw-r-- 1 laura laura   16M Nov  6 16:50 pull_out_reads_BLAST_comparisons.ipynb
# -rw-rw-r-- 1 laura laura  7.2M Oct 23 11:02 pull_out_reads_blast+_nt_archive.csv
# -rw-rw-r-- 1 laura laura  1.5M Oct  3 15:11 pull_out_reads_bwa.ipynb
# -rw-rw-r-- 1 laura laura  1.2M Oct 10 16:50 pull_out_reads_cdna_dna.ipynb
# -rw-rw-r-- 1 laura laura  1.5M Oct  2 10:59 pull_out_reads.ipynb
# -rw-rw-r-- 1 laura laura   218 Sep 29 16:26 pull_out_reads_Kristjan.fa
# -rw-rw-r-- 1 laura laura   13K Oct  3 12:09 pull_out_reads_Kristjan.ipynb
# -rw-rw-r-- 1 laura laura  228K Oct 19 17:38 pull_out_reads_OV_sars_cov2.ipynb
# -rw-rw-r-- 1 laura laura     7 Nov  1 02:58 pull_out_reads_transcript_ids_temp.txt
# -rw-rw-r-- 1 laura laura  111K Aug 17 16:17 pull_out_reads_u131745.csv
# -rw-rw-r-- 1 laura laura  106K Aug 20 09:05 pull_out_reads_u131745_translated.csv
# -rw-rw-r-- 1 laura laura   13K Aug 18 12:46 pull_out_reads_u131745_translated.fasta
# -rw-rw-r-- 1 laura laura  4.0K Aug 17 16:19 pull_out_reads_u26830.csv
# -rw-rw-r-- 1 laura laura  1.9K Aug 17 18:45 pull_out_reads_u26830_translated.csv
# -rw-rw-r-- 1 laura laura  8.8M Jul 24 14:29 raw_multilinear_top20_dict.pickle
# -rw-rw-r-- 1 laura laura   95K Aug 24 21:04 remove_host_bwa.ipynb
# -rw-rw-r-- 1 laura laura  8.3K Aug 18 18:23 remove_host_DIAMOND.ipynb
# -rw-rw-r-- 1 laura laura   15K Jul 27 16:02 simpleRegression.py
# -rw-rw-r-- 1 laura laura   43K Mar 10  2023 SraRunTable.txt
# -rw-rw-r-- 1 laura laura   45K Oct  3 12:06 SRR12698505_2_extracted_u11842_new.fa
# -rw-rw-r-- 1 laura laura   65K Oct  3 12:06 SRR12698505_2_extracted_u34866_new.fa
# drwxrwxr-x 3 laura laura  4.0K Aug 11 13:54 stringent_dlist
# -rw-rw-r-- 1 laura laura  5.3K Nov  2 11:55 temp.csv
# -rw-rw-r-- 1 laura laura    90 Nov  2 11:53 temp.fa
# drwxrwxr-x 2 laura laura  4.0K Oct  3 11:16 test
# -rw-rw-r-- 1 laura laura  487K Aug 19 00:43 tmp.ipynb
# -rw-rw-r-- 1 laura laura  2.1K Jul 21 12:43 tombusviridae_comparison.fa
# -rw-rw-r-- 1 laura laura    10 Oct 19 13:54 txnames.txt
# -rw-rw-r-- 1 laura laura  2.0K Jul 18 19:11 UMI_overlap.ipynb
# -rw-rw-r-- 1 laura laura  7.4K Oct 19 17:57 Untitled1.ipynb
# -rw-rw-r-- 1 laura laura   17K Jul 25 12:42 Untitled.ipynb
# -rw-rw-r-- 1 laura laura   922 Apr 27  2023 viral_loads_fixid.tsv
# -rw-rw-r-- 1 laura laura   40K Aug 10 12:30 virus_dif_before_after_dlist_fix.ipynb
# -rw-rw-r-- 1 laura laura   60K Oct 31 16:50 virus_strandedness_bus+d-list.ipynb
# -rw-rw-r-- 1 laura laura  215K Jun 25 17:06 workflow_comparisons.ipynb
