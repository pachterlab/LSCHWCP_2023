# %% [markdown]
# <a href="https://colab.research.google.com/github/pachterlab/LSCHWCP_2023/blob/main/Notebooks/align_macaque_PBMC_data/8_virus_bwa/3_viral_QC_bwa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Virus count matrix quality control (QC) and virus categorization

# %%
# !pip install -q kb_python anndata
import kb_python.utils as kb_utils
import numpy as np
from scipy import stats
import anndata
import pandas as pd
import json
import os
import glob
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.ticker import MaxNLocator
# %config InlineBackend.figure_format='retina'

def nd(arr):
    """
    Function to transform numpy matrix to nd array.
    """
    return np.asarray(arr).reshape(-1)
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 73.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.2/119.2 kB 16.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 57.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 MB 15.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 68.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.9/21.9 MB 58.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.9/90.9 kB 9.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 6.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 8.3 MB/s eta 0:00:00
#   Building wheel for loompy (setup.py) ... done
#   Building wheel for umap-learn (setup.py) ... done
#   Building wheel for session-info (setup.py) ... done

# %% [markdown]
# ### Load data aligned to PalmDB using translated search kb after removing host sequences by alignment to bwa:

# %%
# Load alignment results from Caltech Data
# !wget https://data.caltech.edu/records/sh33z-hrx98/files/virus_bwa_alignment_results.zip?download=1
# !mv virus_bwa_alignment_results.zip?download=1 virus_bwa_alignment_results.zip
# !unzip virus_bwa_alignment_results.zip
# Out:
# --2023-12-12 19:36:12--  https://data.caltech.edu/records/sh33z-hrx98/files/virus_bwa_alignment_results.zip?download=1
# Resolving data.caltech.edu (data.caltech.edu)... 35.155.11.48
# Connecting to data.caltech.edu (data.caltech.edu)|35.155.11.48|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# Location: https://s3.us-west-2.amazonaws.com/caltechdata/30/96/80e2-29b7-401c-be4c-4c82c8d8b521/data?response-content-type=application%2Foctet-stream&response-content-disposition=attachment%3B%20filename%3Dvirus_bwa_alignment_results.zip&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIARCVIVNNAP7NNDVEA%2F20231212%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20231212T193612Z&X-Amz-Expires=60&X-Amz-SignedHeaders=host&X-Amz-Signature=669219ea275ec56dea44ba386aad99adaa6f6d68880a9442b44e54eb2d5f3d98 [following]
# --2023-12-12 19:36:12--  https://s3.us-west-2.amazonaws.com/caltechdata/30/96/80e2-29b7-401c-be4c-4c82c8d8b521/data?response-content-type=application%2Foctet-stream&response-content-disposition=attachment%3B%20filename%3Dvirus_bwa_alignment_results.zip&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIARCVIVNNAP7NNDVEA%2F20231212%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20231212T193612Z&X-Amz-Expires=60&X-Amz-SignedHeaders=host&X-Amz-Signature=669219ea275ec56dea44ba386aad99adaa6f6d68880a9442b44e54eb2d5f3d98
# Resolving s3.us-west-2.amazonaws.com (s3.us-west-2.amazonaws.com)... 52.92.137.16, 52.92.224.112, 52.92.148.240, ...
# Connecting to s3.us-west-2.amazonaws.com (s3.us-west-2.amazonaws.com)|52.92.137.16|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28654975 (27M) [application/octet-stream]
# Saving to: ‘virus_bwa_alignment_results.zip?download=1’
#
# virus_bwa_alignment 100%[===================>]  27.33M  15.0MB/s    in 1.8s
#
# 2023-12-12 19:36:14 (15.0 MB/s) - ‘virus_bwa_alignment_results.zip?download=1’ saved [28654975/28654975]
#
# Archive:  virus_bwa_alignment_results.zip
#    creating: virus_bwa_alignment_results/
#   inflating: virus_bwa_alignment_results/matrix.cells
#   inflating: virus_bwa_alignment_results/.DS_Store
#   inflating: virus_bwa_alignment_results/run_info.json
#   inflating: virus_bwa_alignment_results/matrix.sample.barcodes
#    creating: virus_bwa_alignment_results/bustools_count/
#   inflating: virus_bwa_alignment_results/bustools_count/output.mtx
#   inflating: virus_bwa_alignment_results/bustools_count/output.barcodes.txt
#   inflating: virus_bwa_alignment_results/bustools_count/output.genes.txt
#   inflating: virus_bwa_alignment_results/bustools_count/output.barcodes.prefix.txt

# %%
# Filepath to counts
X = "virus_bwa_alignment_results/bustools_count/output.mtx"
# Filepath to barcode metadata
var_path = "virus_bwa_alignment_results/bustools_count/output.genes.txt"
# Filepath to gene metadata
obs_path = "virus_bwa_alignment_results/bustools_count/output.barcodes.txt"

# Create AnnData object
palmdb_adata = kb_utils.import_matrix_as_anndata(X, obs_path, var_path)
palmdb_adata
# Out:
# /usr/local/lib/python3.10/dist-packages/anndata/_core/anndata.py:1897: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /usr/local/lib/python3.10/dist-packages/anndata/_core/anndata.py:1897: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# AnnData object with n_obs × n_vars = 8299834 × 99228

# %%
# Add sample barcodes to adata
sb_file = open("virus_bwa_alignment_results/bustools_count/output.barcodes.prefix.txt")
sample_barcodes = sb_file.read().splitlines()
sb_file.close()

# Only use last 16 bases because sample barcode is always 16 bases in length
palmdb_adata.obs["sample_barcode"] = [bc[-16:] for bc in sample_barcodes]

# %%
# Create barcode to sample lookup
bc2sample_df = pd.DataFrame()

b_file = open("virus_bwa_alignment_results/matrix.sample.barcodes")
barcodes = b_file.read().splitlines()
b_file.close()

s_file = open("virus_bwa_alignment_results/matrix.cells")
samples = s_file.read().splitlines()
s_file.close()

bc2sample_df["sample_barcode"] = barcodes
bc2sample_df["srr"] = samples
bc2sample_df
# Out:
#        sample_barcode          srr
# 0    AAAAAAAAAAAAAAAA  SRR12698573
# 1    AAAAAAAAAAAAAAAC  SRR12698501
# 2    AAAAAAAAAAAAAAAG  SRR12698523
# 3    AAAAAAAAAAAAAAAT  SRR12698521
# 4    AAAAAAAAAAAAAACA  SRR12698566
# ..                ...          ...
# 101  AAAAAAAAAAAACGCC  SRR12698557
# 102  AAAAAAAAAAAACGCG  SRR12698597
# 103  AAAAAAAAAAAACGCT  SRR12698516
# 104  AAAAAAAAAAAACGGA  SRR12698540
# 105  AAAAAAAAAAAACGGC  SRR12698520
#
# [106 rows x 2 columns]

# %%
palmdb_adata.obs["barcode"] = palmdb_adata.obs.index.values
palmdb_adata.obs = palmdb_adata.obs.merge(bc2sample_df, on="sample_barcode", how="left").set_index("barcode", drop=False)
palmdb_adata.obs
# Out:
#                 sample_barcode       barcode          srr
# barcode
# AAAAAAAAAAAA  AAAAAAAAAAAAAAAA  AAAAAAAAAAAA  SRR12698573
# AAAAAAAGACTC  AAAAAAAAAAAAAAAA  AAAAAAAGACTC  SRR12698573
# AAAAAAATACAG  AAAAAAAAAAAAAAAA  AAAAAAATACAG  SRR12698573
# AAAAAACCACCT  AAAAAAAAAAAAAAAA  AAAAAACCACCT  SRR12698573
# AAAAAACCCGTA  AAAAAAAAAAAAAAAA  AAAAAACCCGTA  SRR12698573
# ...                        ...           ...          ...
# TTTTTTGCCTGT  AAAAAAAAAAAACGGC  TTTTTTGCCTGT  SRR12698520
# TTTTTTGGCCGT  AAAAAAAAAAAACGGC  TTTTTTGGCCGT  SRR12698520
# TTTTTTTTAGCC  AAAAAAAAAAAACGGC  TTTTTTTTAGCC  SRR12698520
# TTTTTTTTTATA  AAAAAAAAAAAACGGC  TTTTTTTTTATA  SRR12698520
# TTTTTTTTTTTT  AAAAAAAAAAAACGGC  TTTTTTTTTTTT  SRR12698520
#
# [8299834 rows x 3 columns]

# %% [markdown]
# ### Add timepoints from SRR metadata:

# %%
# !wget https://raw.githubusercontent.com/pachterlab/LSCHWCP_2023/main/Notebooks/Supp_Fig_3/Supp_Fig_3abc/PRJNA665227_SraRunTable.txt
srr_meta = pd.read_csv("PRJNA665227_SraRunTable.txt", sep=",")

# Only keep relevent data
srr_meta["mdck_spike_in"] = srr_meta["mdck_spike_in"].fillna(False).values
srr_meta = srr_meta[["Run", "donor_animal", "Experiment", "mdck_spike_in", "hours_post_innoculation", "day_post_infection"]]
srr_meta
# Out:
# --2023-12-12 19:37:17--  https://raw.githubusercontent.com/pachterlab/LSCHWCP_2023/main/Notebooks/Supp_Fig_3/Supp_Fig_3abc/PRJNA665227_SraRunTable.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 43703 (43K) [text/plain]
# Saving to: ‘PRJNA665227_SraRunTable.txt’
#
# PRJNA665227_SraRunT 100%[===================>]  42.68K  --.-KB/s    in 0.01s
#
# 2023-12-12 19:37:17 (3.51 MB/s) - ‘PRJNA665227_SraRunTable.txt’ saved [43703/43703]
#              Run donor_animal  Experiment  mdck_spike_in  \
# 0    SRR12698499         NHP1  SRX9178097          False
# 1    SRR12698500         NHP1  SRX9178098          False
# 2    SRR12698501         NHP1  SRX9178099          False
# 3    SRR12698502         NHP1  SRX9178100          False
# 4    SRR12698503         NHP1  SRX9178101          False
# ..           ...          ...         ...            ...
# 101  SRR12698600        NHP10  SRX9178198          False
# 102  SRR12698601        NHP24  SRX9178199          False
# 103  SRR12698602        NHP24  SRX9178200          False
# 104  SRR12698603        NHP08  SRX9178201          False
# 105  SRR12698604        NHP15  SRX9178202          False
#
#      hours_post_innoculation  day_post_infection
# 0                        4.0                 NaN
# 1                        4.0                 NaN
# 2                        4.0                 NaN
# 3                        4.0                 NaN
# 4                        4.0                 NaN
# ..                       ...                 ...
# 101                      NaN                 7.0
# 102                      NaN                 6.0
# 103                      NaN                 6.0
# 104                      NaN                -4.0
# 105                      NaN                 3.0
#
# [106 rows x 6 columns]

# %%
palmdb_adata.obs = (
        palmdb_adata
        .obs.merge(srr_meta, left_on="srr", right_on="Run", how="left")
        .set_index("barcode", drop=False)
    )

palmdb_adata.obs
# Out:
#                 sample_barcode       barcode          srr          Run  \
# barcode
# AAAAAAAAAAAA  AAAAAAAAAAAAAAAA  AAAAAAAAAAAA  SRR12698573  SRR12698573
# AAAAAAAGACTC  AAAAAAAAAAAAAAAA  AAAAAAAGACTC  SRR12698573  SRR12698573
# AAAAAAATACAG  AAAAAAAAAAAAAAAA  AAAAAAATACAG  SRR12698573  SRR12698573
# AAAAAACCACCT  AAAAAAAAAAAAAAAA  AAAAAACCACCT  SRR12698573  SRR12698573
# AAAAAACCCGTA  AAAAAAAAAAAAAAAA  AAAAAACCCGTA  SRR12698573  SRR12698573
# ...                        ...           ...          ...          ...
# TTTTTTGCCTGT  AAAAAAAAAAAACGGC  TTTTTTGCCTGT  SRR12698520  SRR12698520
# TTTTTTGGCCGT  AAAAAAAAAAAACGGC  TTTTTTGGCCGT  SRR12698520  SRR12698520
# TTTTTTTTAGCC  AAAAAAAAAAAACGGC  TTTTTTTTAGCC  SRR12698520  SRR12698520
# TTTTTTTTTATA  AAAAAAAAAAAACGGC  TTTTTTTTTATA  SRR12698520  SRR12698520
# TTTTTTTTTTTT  AAAAAAAAAAAACGGC  TTTTTTTTTTTT  SRR12698520  SRR12698520
#
#              donor_animal  Experiment  mdck_spike_in  hours_post_innoculation  \
# barcode
# AAAAAAAAAAAA        NHP23  SRX9178171           True                      NaN
# AAAAAAAGACTC        NHP23  SRX9178171           True                      NaN
# AAAAAAATACAG        NHP23  SRX9178171           True                      NaN
# AAAAAACCACCT        NHP23  SRX9178171           True                      NaN
# AAAAAACCCGTA        NHP23  SRX9178171           True                      NaN
# ...                   ...         ...            ...                      ...
# TTTTTTGCCTGT         NHP2  SRX9178118          False                     24.0
# TTTTTTGGCCGT         NHP2  SRX9178118          False                     24.0
# TTTTTTTTAGCC         NHP2  SRX9178118          False                     24.0
# TTTTTTTTTATA         NHP2  SRX9178118          False                     24.0
# TTTTTTTTTTTT         NHP2  SRX9178118          False                     24.0
#
#               day_post_infection
# barcode
# AAAAAAAAAAAA                 6.0
# AAAAAAAGACTC                 6.0
# AAAAAAATACAG                 6.0
# AAAAAACCACCT                 6.0
# AAAAAACCCGTA                 6.0
# ...                          ...
# TTTTTTGCCTGT                 NaN
# TTTTTTGGCCGT                 NaN
# TTTTTTTTAGCC                 NaN
# TTTTTTTTTATA                 NaN
# TTTTTTTTTTTT                 NaN
#
# [8299834 rows x 9 columns]

# %% [markdown]
# Create clean dpi column:

# %%
# Join day_post_infection and hours_post_innoculation columns
palmdb_adata.obs["dpi"] = palmdb_adata.obs["day_post_infection"].fillna(palmdb_adata.obs["hours_post_innoculation"]).astype(int)

# Add h/d accession to denote hours/days
palmdb_adata.obs["dpi_accessions"] = np.where(palmdb_adata.obs["hours_post_innoculation"].isna(), "d", "h")
palmdb_adata.obs["dpi_clean"] = palmdb_adata.obs["dpi"].astype(str) + palmdb_adata.obs["dpi_accessions"].astype(str)

palmdb_adata.obs
# Out:
#                 sample_barcode       barcode          srr          Run  \
# barcode
# AAAAAAAAAAAA  AAAAAAAAAAAAAAAA  AAAAAAAAAAAA  SRR12698573  SRR12698573
# AAAAAAAGACTC  AAAAAAAAAAAAAAAA  AAAAAAAGACTC  SRR12698573  SRR12698573
# AAAAAAATACAG  AAAAAAAAAAAAAAAA  AAAAAAATACAG  SRR12698573  SRR12698573
# AAAAAACCACCT  AAAAAAAAAAAAAAAA  AAAAAACCACCT  SRR12698573  SRR12698573
# AAAAAACCCGTA  AAAAAAAAAAAAAAAA  AAAAAACCCGTA  SRR12698573  SRR12698573
# ...                        ...           ...          ...          ...
# TTTTTTGCCTGT  AAAAAAAAAAAACGGC  TTTTTTGCCTGT  SRR12698520  SRR12698520
# TTTTTTGGCCGT  AAAAAAAAAAAACGGC  TTTTTTGGCCGT  SRR12698520  SRR12698520
# TTTTTTTTAGCC  AAAAAAAAAAAACGGC  TTTTTTTTAGCC  SRR12698520  SRR12698520
# TTTTTTTTTATA  AAAAAAAAAAAACGGC  TTTTTTTTTATA  SRR12698520  SRR12698520
# TTTTTTTTTTTT  AAAAAAAAAAAACGGC  TTTTTTTTTTTT  SRR12698520  SRR12698520
#
#              donor_animal  Experiment  mdck_spike_in  hours_post_innoculation  \
# barcode
# AAAAAAAAAAAA        NHP23  SRX9178171           True                      NaN
# AAAAAAAGACTC        NHP23  SRX9178171           True                      NaN
# AAAAAAATACAG        NHP23  SRX9178171           True                      NaN
# AAAAAACCACCT        NHP23  SRX9178171           True                      NaN
# AAAAAACCCGTA        NHP23  SRX9178171           True                      NaN
# ...                   ...         ...            ...                      ...
# TTTTTTGCCTGT         NHP2  SRX9178118          False                     24.0
# TTTTTTGGCCGT         NHP2  SRX9178118          False                     24.0
# TTTTTTTTAGCC         NHP2  SRX9178118          False                     24.0
# TTTTTTTTTATA         NHP2  SRX9178118          False                     24.0
# TTTTTTTTTTTT         NHP2  SRX9178118          False                     24.0
#
#               day_post_infection  dpi dpi_accessions dpi_clean
# barcode
# AAAAAAAAAAAA                 6.0    6              d        6d
# AAAAAAAGACTC                 6.0    6              d        6d
# AAAAAAATACAG                 6.0    6              d        6d
# AAAAAACCACCT                 6.0    6              d        6d
# AAAAAACCCGTA                 6.0    6              d        6d
# ...                          ...  ...            ...       ...
# TTTTTTGCCTGT                 NaN   24              h       24h
# TTTTTTGGCCGT                 NaN   24              h       24h
# TTTTTTTTAGCC                 NaN   24              h       24h
# TTTTTTTTTATA                 NaN   24              h       24h
# TTTTTTTTTTTT                 NaN   24              h       24h
#
# [8299834 rows x 12 columns]

# %% [markdown]
# ___

# %% [markdown]
# # Add macaque and canine metadata to virus count matrix:

# %%
# Download host count matrices from Caltech Data
# Generated here: https://github.com/pachterlab/LSCHWCP_2023/tree/main/Notebooks/Supp_Fig_3/Supp_Fig_3abc
# !wget https://data.caltech.edu/records/sh33z-hrx98/files/macaque_QC_norm_leiden_celltypes.h5ad?download=1
# !mv macaque_QC_norm_leiden_celltypes.h5ad?download=1 macaque_QC_norm_leiden_celltypes.h5ad
# !wget https://data.caltech.edu/records/sh33z-hrx98/files/host_QC.h5ad?download=1
# !mv host_QC.h5ad?download=1 host_QC.h5ad

# Macaque only
mac_adata = anndata.read("macaque_QC_norm_leiden_celltypes.h5ad")
mac_adata

# All host
host_adata = anndata.read("host_QC.h5ad")
host_adata
# Out:
# --2023-12-12 19:37:24--  https://data.caltech.edu/records/sh33z-hrx98/files/macaque_QC_norm_leiden_celltypes.h5ad?download=1
# Resolving data.caltech.edu (data.caltech.edu)... 35.155.11.48
# Connecting to data.caltech.edu (data.caltech.edu)|35.155.11.48|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# Location: https://s3.us-west-2.amazonaws.com/caltechdata/eb/83/1422-8c5d-4162-b72c-66f5807f91f1/data?response-content-type=application%2Foctet-stream&response-content-disposition=attachment%3B%20filename%3Dmacaque_QC_norm_leiden_celltypes.h5ad&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIARCVIVNNAP7NNDVEA%2F20231212%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20231212T193724Z&X-Amz-Expires=60&X-Amz-SignedHeaders=host&X-Amz-Signature=7a1b36f9600ef77daaf506599d2736dd76ba1cd2dbd602c0c47c16f0ce85ccfe [following]
# --2023-12-12 19:37:24--  https://s3.us-west-2.amazonaws.com/caltechdata/eb/83/1422-8c5d-4162-b72c-66f5807f91f1/data?response-content-type=application%2Foctet-stream&response-content-disposition=attachment%3B%20filename%3Dmacaque_QC_norm_leiden_celltypes.h5ad&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIARCVIVNNAP7NNDVEA%2F20231212%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20231212T193724Z&X-Amz-Expires=60&X-Amz-SignedHeaders=host&X-Amz-Signature=7a1b36f9600ef77daaf506599d2736dd76ba1cd2dbd602c0c47c16f0ce85ccfe
# Resolving s3.us-west-2.amazonaws.com (s3.us-west-2.amazonaws.com)... 52.92.153.56, 52.92.236.184, 52.92.137.248, ...
# Connecting to s3.us-west-2.amazonaws.com (s3.us-west-2.amazonaws.com)|52.92.153.56|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2511800409 (2.3G) [application/octet-stream]
# Saving to: ‘macaque_QC_norm_leiden_celltypes.h5ad?download=1’
#
# macaque_QC_norm_lei 100%[===================>]   2.34G  15.6MB/s    in 2m 28s
#
# 2023-12-12 19:39:52 (16.2 MB/s) - ‘macaque_QC_norm_leiden_celltypes.h5ad?download=1’ saved [2511800409/2511800409]
#
# --2023-12-12 19:39:53--  https://data.caltech.edu/records/sh33z-hrx98/files/host_QC.h5ad?download=1
# Resolving data.caltech.edu (data.caltech.edu)... 35.155.11.48
# Connecting to data.caltech.edu (data.caltech.edu)|35.155.11.48|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# Location: https://s3.us-west-2.amazonaws.com/caltechdata/b4/35/81cf-894d-4e8a-8b5e-8e880858f0ad/data?response-content-type=application%2Foctet-stream&response-content-disposition=attachment%3B%20filename%3Dhost_QC.h5ad&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIARCVIVNNAP7NNDVEA%2F20231212%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20231212T193953Z&X-Amz-Expires=60&X-Amz-SignedHeaders=host&X-Amz-Signature=f73e21131d6eb6b2f370be12a5e9de442bd1683095bcbef437aea518f1af337c [following]
# --2023-12-12 19:39:53--  https://s3.us-west-2.amazonaws.com/caltechdata/b4/35/81cf-894d-4e8a-8b5e-8e880858f0ad/data?response-content-type=application%2Foctet-stream&response-content-disposition=attachment%3B%20filename%3Dhost_QC.h5ad&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIARCVIVNNAP7NNDVEA%2F20231212%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20231212T193953Z&X-Amz-Expires=60&X-Amz-SignedHeaders=host&X-Amz-Signature=f73e21131d6eb6b2f370be12a5e9de442bd1683095bcbef437aea518f1af337c
# Resolving s3.us-west-2.amazonaws.com (s3.us-west-2.amazonaws.com)... 52.92.194.80, 52.92.138.136, 52.218.233.160, ...
# Connecting to s3.us-west-2.amazonaws.com (s3.us-west-2.amazonaws.com)|52.92.194.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1419260663 (1.3G) [application/octet-stream]
# Saving to: ‘host_QC.h5ad?download=1’
#
# host_QC.h5ad?downlo 100%[===================>]   1.32G  14.6MB/s    in 86s
#
# 2023-12-12 19:41:19 (15.7 MB/s) - ‘host_QC.h5ad?download=1’ saved [1419260663/1419260663]
# /usr/local/lib/python3.10/dist-packages/anndata/__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/anndata/_core/anndata.py:183: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /usr/local/lib/python3.10/dist-packages/anndata/_core/anndata.py:1897: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /usr/local/lib/python3.10/dist-packages/anndata/__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/anndata/_core/anndata.py:183: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /usr/local/lib/python3.10/dist-packages/anndata/_core/anndata.py:1897: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# AnnData object with n_obs × n_vars = 237658 × 66553
#     obs: 'sample_barcode', 'barcode', 'srr', 'n_counts', 'n_genes', 'percent_mito', 'species'
#     var: 'gene_id', 'species'

# %%
palmdb_adata.obs = palmdb_adata.obs.drop("barcode", axis=1)
palmdb_adata.obs = palmdb_adata.obs.merge(
    mac_adata.obs[["srr", "leiden", "celltype_clusters", "celltype"]],
    on=["barcode", "srr"],
    how="left",
    validate="one_to_one"
)

# %%
palmdb_adata.obs[palmdb_adata.obs["celltype"].notnull()]
# Out:
#                 sample_barcode          srr          Run donor_animal  \
# barcode
# AAAAAAGCATCA  AAAAAAAAAAAAAAAA  SRR12698573  SRR12698573        NHP23
# AAAAAATCGACC  AAAAAAAAAAAAAAAA  SRR12698573  SRR12698573        NHP23
# AAAAATAGTGGA  AAAAAAAAAAAAAAAA  SRR12698573  SRR12698573        NHP23
# AAAACCAGGTAT  AAAAAAAAAAAAAAAA  SRR12698573  SRR12698573        NHP23
# AAAACTCACGTG  AAAAAAAAAAAAAAAA  SRR12698573  SRR12698573        NHP23
# ...                        ...          ...          ...          ...
# TTTTTCAAGGGG  AAAAAAAAAAAACGGC  SRR12698520  SRR12698520         NHP2
# TTTTTCCGTCGA  AAAAAAAAAAAACGGC  SRR12698520  SRR12698520         NHP2
# TTTTTCTTAATG  AAAAAAAAAAAACGGC  SRR12698520  SRR12698520         NHP2
# TTTTTGTCGGAG  AAAAAAAAAAAACGGC  SRR12698520  SRR12698520         NHP2
# TTTTTTACGAAG  AAAAAAAAAAAACGGC  SRR12698520  SRR12698520         NHP2
#
#               Experiment  mdck_spike_in  hours_post_innoculation  \
# barcode
# AAAAAAGCATCA  SRX9178171           True                      NaN
# AAAAAATCGACC  SRX9178171           True                      NaN
# AAAAATAGTGGA  SRX9178171           True                      NaN
# AAAACCAGGTAT  SRX9178171           True                      NaN
# AAAACTCACGTG  SRX9178171           True                      NaN
# ...                  ...            ...                      ...
# TTTTTCAAGGGG  SRX9178118          False                     24.0
# TTTTTCCGTCGA  SRX9178118          False                     24.0
# TTTTTCTTAATG  SRX9178118          False                     24.0
# TTTTTGTCGGAG  SRX9178118          False                     24.0
# TTTTTTACGAAG  SRX9178118          False                     24.0
#
#               day_post_infection  dpi dpi_accessions dpi_clean leiden  \
# barcode
# AAAAAAGCATCA                 6.0    6              d        6d      6
# AAAAAATCGACC                 6.0    6              d        6d      2
# AAAAATAGTGGA                 6.0    6              d        6d      7
# AAAACCAGGTAT                 6.0    6              d        6d      2
# AAAACTCACGTG                 6.0    6              d        6d      2
# ...                          ...  ...            ...       ...    ...
# TTTTTCAAGGGG                 NaN   24              h       24h      3
# TTTTTCCGTCGA                 NaN   24              h       24h      0
# TTTTTCTTAATG                 NaN   24              h       24h      3
# TTTTTGTCGGAG                 NaN   24              h       24h      0
# TTTTTTACGAAG                 NaN   24              h       24h     11
#
#              celltype_clusters        celltype
# barcode
# AAAAAAGCATCA         T cells 5         T cells
# AAAAAATCGACC         B cells 6         B cells
# AAAAATAGTGGA       Monocytes 2       Monocytes
# AAAACCAGGTAT         B cells 6         B cells
# AAAACTCACGTG         B cells 6         B cells
# ...                        ...             ...
# TTTTTCAAGGGG  Natural killer 1  Natural killer
# TTTTTCCGTCGA         B cells 4         B cells
# TTTTTCTTAATG  Natural killer 1  Natural killer
# TTTTTGTCGGAG         B cells 4         B cells
# TTTTTTACGAAG         B cells 1         B cells
#
# [193604 rows x 14 columns]

# %%
palmdb_adata.obs = palmdb_adata.obs.merge(
    host_adata.obs[["srr", "species"]],
    on=["barcode", "srr"],
    how="left",
    validate="one_to_one"
)

# %%
palmdb_adata.obs[palmdb_adata.obs["species"].notnull()]
# Out:
#                 sample_barcode          srr          Run donor_animal  \
# barcode
# AAAAAAGCATCA  AAAAAAAAAAAAAAAA  SRR12698573  SRR12698573        NHP23
# AAAAAATCGACC  AAAAAAAAAAAAAAAA  SRR12698573  SRR12698573        NHP23
# AAAAATAGTGGA  AAAAAAAAAAAAAAAA  SRR12698573  SRR12698573        NHP23
# AAAACCAGGTAT  AAAAAAAAAAAAAAAA  SRR12698573  SRR12698573        NHP23
# AAAACCGTCCCT  AAAAAAAAAAAAAAAA  SRR12698573  SRR12698573        NHP23
# ...                        ...          ...          ...          ...
# TTTTTCAAGGGG  AAAAAAAAAAAACGGC  SRR12698520  SRR12698520         NHP2
# TTTTTCCGTCGA  AAAAAAAAAAAACGGC  SRR12698520  SRR12698520         NHP2
# TTTTTCTTAATG  AAAAAAAAAAAACGGC  SRR12698520  SRR12698520         NHP2
# TTTTTGTCGGAG  AAAAAAAAAAAACGGC  SRR12698520  SRR12698520         NHP2
# TTTTTTACGAAG  AAAAAAAAAAAACGGC  SRR12698520  SRR12698520         NHP2
#
#               Experiment  mdck_spike_in  hours_post_innoculation  \
# barcode
# AAAAAAGCATCA  SRX9178171           True                      NaN
# AAAAAATCGACC  SRX9178171           True                      NaN
# AAAAATAGTGGA  SRX9178171           True                      NaN
# AAAACCAGGTAT  SRX9178171           True                      NaN
# AAAACCGTCCCT  SRX9178171           True                      NaN
# ...                  ...            ...                      ...
# TTTTTCAAGGGG  SRX9178118          False                     24.0
# TTTTTCCGTCGA  SRX9178118          False                     24.0
# TTTTTCTTAATG  SRX9178118          False                     24.0
# TTTTTGTCGGAG  SRX9178118          False                     24.0
# TTTTTTACGAAG  SRX9178118          False                     24.0
#
#               day_post_infection  dpi dpi_accessions dpi_clean leiden  \
# barcode
# AAAAAAGCATCA                 6.0    6              d        6d      6
# AAAAAATCGACC                 6.0    6              d        6d      2
# AAAAATAGTGGA                 6.0    6              d        6d      7
# AAAACCAGGTAT                 6.0    6              d        6d      2
# AAAACCGTCCCT                 6.0    6              d        6d    NaN
# ...                          ...  ...            ...       ...    ...
# TTTTTCAAGGGG                 NaN   24              h       24h      3
# TTTTTCCGTCGA                 NaN   24              h       24h      0
# TTTTTCTTAATG                 NaN   24              h       24h      3
# TTTTTGTCGGAG                 NaN   24              h       24h      0
# TTTTTTACGAAG                 NaN   24              h       24h     11
#
#              celltype_clusters        celltype         species
# barcode
# AAAAAAGCATCA         T cells 5         T cells  macaca_mulatta
# AAAAAATCGACC         B cells 6         B cells  macaca_mulatta
# AAAAATAGTGGA       Monocytes 2       Monocytes  macaca_mulatta
# AAAACCAGGTAT         B cells 6         B cells  macaca_mulatta
# AAAACCGTCCCT               NaN             NaN          unkown
# ...                        ...             ...             ...
# TTTTTCAAGGGG  Natural killer 1  Natural killer  macaca_mulatta
# TTTTTCCGTCGA         B cells 4         B cells  macaca_mulatta
# TTTTTCTTAATG  Natural killer 1  Natural killer  macaca_mulatta
# TTTTTGTCGGAG         B cells 4         B cells  macaca_mulatta
# TTTTTTACGAAG         B cells 1         B cells  macaca_mulatta
#
# [223629 rows x 15 columns]

# %% [markdown]
# # Threshold viruses to keep only those seen in at least [virus_threshold] QC'd cells

# %%
# Remove all cells that did not pass macaque or canine filtering
palmdb_adata = palmdb_adata[palmdb_adata.obs["species"].notnull(), :]
palmdb_adata.obs
# Out:
#                 sample_barcode          srr          Run donor_animal  \
# barcode
# AAAAAAGCATCA  AAAAAAAAAAAAAAAA  SRR12698573  SRR12698573        NHP23
# AAAAAATCGACC  AAAAAAAAAAAAAAAA  SRR12698573  SRR12698573        NHP23
# AAAAATAGTGGA  AAAAAAAAAAAAAAAA  SRR12698573  SRR12698573        NHP23
# AAAACCAGGTAT  AAAAAAAAAAAAAAAA  SRR12698573  SRR12698573        NHP23
# AAAACCGTCCCT  AAAAAAAAAAAAAAAA  SRR12698573  SRR12698573        NHP23
# ...                        ...          ...          ...          ...
# TTTTTCAAGGGG  AAAAAAAAAAAACGGC  SRR12698520  SRR12698520         NHP2
# TTTTTCCGTCGA  AAAAAAAAAAAACGGC  SRR12698520  SRR12698520         NHP2
# TTTTTCTTAATG  AAAAAAAAAAAACGGC  SRR12698520  SRR12698520         NHP2
# TTTTTGTCGGAG  AAAAAAAAAAAACGGC  SRR12698520  SRR12698520         NHP2
# TTTTTTACGAAG  AAAAAAAAAAAACGGC  SRR12698520  SRR12698520         NHP2
#
#               Experiment  mdck_spike_in  hours_post_innoculation  \
# barcode
# AAAAAAGCATCA  SRX9178171           True                      NaN
# AAAAAATCGACC  SRX9178171           True                      NaN
# AAAAATAGTGGA  SRX9178171           True                      NaN
# AAAACCAGGTAT  SRX9178171           True                      NaN
# AAAACCGTCCCT  SRX9178171           True                      NaN
# ...                  ...            ...                      ...
# TTTTTCAAGGGG  SRX9178118          False                     24.0
# TTTTTCCGTCGA  SRX9178118          False                     24.0
# TTTTTCTTAATG  SRX9178118          False                     24.0
# TTTTTGTCGGAG  SRX9178118          False                     24.0
# TTTTTTACGAAG  SRX9178118          False                     24.0
#
#               day_post_infection  dpi dpi_accessions dpi_clean leiden  \
# barcode
# AAAAAAGCATCA                 6.0    6              d        6d      6
# AAAAAATCGACC                 6.0    6              d        6d      2
# AAAAATAGTGGA                 6.0    6              d        6d      7
# AAAACCAGGTAT                 6.0    6              d        6d      2
# AAAACCGTCCCT                 6.0    6              d        6d    NaN
# ...                          ...  ...            ...       ...    ...
# TTTTTCAAGGGG                 NaN   24              h       24h      3
# TTTTTCCGTCGA                 NaN   24              h       24h      0
# TTTTTCTTAATG                 NaN   24              h       24h      3
# TTTTTGTCGGAG                 NaN   24              h       24h      0
# TTTTTTACGAAG                 NaN   24              h       24h     11
#
#              celltype_clusters        celltype         species
# barcode
# AAAAAAGCATCA         T cells 5         T cells  macaca_mulatta
# AAAAAATCGACC         B cells 6         B cells  macaca_mulatta
# AAAAATAGTGGA       Monocytes 2       Monocytes  macaca_mulatta
# AAAACCAGGTAT         B cells 6         B cells  macaca_mulatta
# AAAACCGTCCCT               NaN             NaN          unkown
# ...                        ...             ...             ...
# TTTTTCAAGGGG  Natural killer 1  Natural killer  macaca_mulatta
# TTTTTCCGTCGA         B cells 4         B cells  macaca_mulatta
# TTTTTCTTAATG  Natural killer 1  Natural killer  macaca_mulatta
# TTTTTGTCGGAG         B cells 4         B cells  macaca_mulatta
# TTTTTTACGAAG         B cells 1         B cells  macaca_mulatta
#
# [223629 rows x 15 columns]

# %%
# Remove all viruses that were not detected in at least [virus_threshold] cells across the entire dataset
virus_threshold = 1

palmdb_adata = palmdb_adata[:, (palmdb_adata.X > 0).sum(axis=0) >= virus_threshold]
palmdb_adata
# Out:
# View of AnnData object with n_obs × n_vars = 223629 × 4686
#     obs: 'sample_barcode', 'srr', 'Run', 'donor_animal', 'Experiment', 'mdck_spike_in', 'hours_post_innoculation', 'day_post_infection', 'dpi', 'dpi_accessions', 'dpi_clean', 'leiden', 'celltype_clusters', 'celltype', 'species'

# %% [markdown]
# # Binarize virus matrix

# %%
# Save raw counts before binarizing
palmdb_adata.raw = palmdb_adata
# Out:
# /usr/local/lib/python3.10/dist-packages/anndata/_core/anndata.py:1897: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /usr/local/lib/python3.10/dist-packages/anndata/_core/anndata.py:1897: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
# Replace all positive integers with 1
palmdb_adata.X[palmdb_adata.X > 0] = 1

# %%
palmdb_adata.raw.X.sum()
# Out:
# 74457.0

# %%
palmdb_adata.raw.X.max()
# Out:
# 1.0

# %%
palmdb_adata.X.sum()
# Out:
# 74457.0

# %%
palmdb_adata.X.max()
# Out:
# 1.0

# %% [markdown]
# # Merge timepoints

# %%
# Merge 7d and 8d timepoints
new_tps = []
for tp in palmdb_adata.obs["dpi_clean"].values:
    if tp == "7d" or tp == "8d":
        new_tps.append("7d/8d")
    else:
        new_tps.append(tp)

palmdb_adata.obs["dpi_clean_merged"] = new_tps

# %% [markdown]
# # Mark viruses seen in both canine and macaque cells as "shared"

# %%
def yex(ax, c="grey", alpha=0.75):
    """
    Funciton to add linear graph to plot.
    Call after defining x and y scales
    """
    lims = [
        np.min([ax.get_xlim(), ax.get_ylim()]),  # min of both axes
        np.max([ax.get_xlim(), ax.get_ylim()]),  # max of both axes
    ]
    # Plot both limits against each other
    ax.plot(lims, lims, c, alpha=alpha, zorder=0, lw=1)
    ax.set(**{
        "aspect": "equal",
        "xlim": lims,
        "ylim": lims
    })
    return ax

# %% [markdown]
# Viruses along the y=x line will have equal fractions of positive cells in both MDCK and macaque cells and are likely shared. We will define a log (increases as fractions also increase) minimum distance between the MDCK and macaque fractions.

# %%
# Minimum fraction of positive cells per virus per species
min_frac_threshold = 0.0005

print(f"This equals to a minimum of {min_frac_threshold * len(palmdb_adata.obs[palmdb_adata.obs['species'] == 'macaca_mulatta'])} positive cells for macaque")
# Out:
# This equals to a minimum of 96.802 positive cells for macaque

# %%
# %%time
# Fold change between fractions of pos cells within which viruses will be considered shared
fold_change = 2

# Maximum number of cells allowed from other species for "_only" assignments
min_num_cells = 7

# Get fraction of positive cells for each virus for each species
mac_fractions = nd(palmdb_adata[palmdb_adata.obs["species"] == "macaca_mulatta", :].X.sum(axis=0)) / len(palmdb_adata.obs[palmdb_adata.obs["species"] == "macaca_mulatta"])
can_fractions = nd(palmdb_adata[palmdb_adata.obs["species"] == "canis_lupus_familiaris", :].X.sum(axis=0)) / len(palmdb_adata.obs[palmdb_adata.obs["species"] == "canis_lupus_familiaris"])

v_types = []
for mac_frac, can_frac in zip(mac_fractions, can_fractions):
    if mac_frac < min_frac_threshold and can_frac < min_frac_threshold:
        v_types.append("below_threshold")
    elif mac_frac > can_frac and mac_frac / can_frac <= fold_change:
        v_types.append("shared")
    elif can_frac > mac_frac and can_frac / mac_frac <= fold_change:
        v_types.append("shared")
    elif mac_frac > can_frac and can_frac <= (min_num_cells / len(palmdb_adata.obs[palmdb_adata.obs["species"] == "canis_lupus_familiaris"])): # Allow [min_num_cells] positive cells in the other species
        v_types.append("macaca_only")
    elif can_frac > mac_frac and mac_frac <= (min_num_cells / len(palmdb_adata.obs[palmdb_adata.obs["species"] == "macaca_mulatta"])):
        v_types.append("canis_only")
    else:
        v_types.append("undefined")
# Out:
# <timed exec>:15: RuntimeWarning: divide by zero encountered in double_scalars
# CPU times: user 1.12 s, sys: 8.25 ms, total: 1.13 s
# Wall time: 1.15 s

# %%
palmdb_adata.var["v_type"] = v_types

# %%
fig, ax = plt.subplots(figsize=(12, 10))
fontsize = 14
vmax = 5.0

all_v_types = ["macaca_only", "canis_only", "shared", "undefined", "below_threshold"]
labels = ["macaque only", "MDCK only", "shared", "undefined", "below threshold"]

# Generate colormaps (removing lightest values for visibility)
edgecolors = ["green", "blue", "red", "grey", "lightgrey"]
cmaps_orig = [plt.cm.Greens, plt.cm.Blues, plt.cm.Oranges, plt.cm.Greys]
min_val, max_val = 0.25, 1.0
n = 20
cmaps = []
for orig_cmap in cmaps_orig:
    colors = orig_cmap(np.linspace(min_val, max_val, n))
    cmaps.append(mpl.colors.LinearSegmentedColormap.from_list("mycmap", colors))

for i, v_type in enumerate(all_v_types):
    # # Plot number of canis over macaque UMIs
    # x = (np.array(palmdb_adata[palmdb_adata.obs["species"] == "macaca_mulatta", palmdb_adata.var["v_type"] == v_type].X.sum(axis=0))).flatten()
    # y = (np.array(palmdb_adata[palmdb_adata.obs["species"] == "canis_lupus_familiaris", palmdb_adata.var["v_type"] == v_type].X.sum(axis=0))).flatten()

    # Plot fraction of canis and macaque positive cells
    x = nd(palmdb_adata[palmdb_adata.obs["species"] == "macaca_mulatta", palmdb_adata.var["v_type"] == v_type].X.sum(axis=0)) / len(palmdb_adata.obs[palmdb_adata.obs["species"] == "macaca_mulatta"])
    y = nd(palmdb_adata[palmdb_adata.obs["species"] == "canis_lupus_familiaris", palmdb_adata.var["v_type"] == v_type].X.sum(axis=0)) / len(palmdb_adata.obs[palmdb_adata.obs["species"] == "canis_lupus_familiaris"])

    # Convert to percentages
    x = x*100
    y = y*100

    # Histogram data to show point density
    bins = [1500, 1500]
    hh, locx, locy = np.histogram2d(x, y, bins=bins)
    z = np.array([hh[np.argmax(a<=locx[1:]),np.argmax(b<=locy[1:])] for a,b in zip(x,y)])
    idx = z.argsort()
    x2, y2, z2 = x[idx], y[idx], z[idx]

    print(z2.max())

    # Normalize colormaps to same range
    if v_type != "below_threshold":
        scatter = ax.scatter(x2, y2, c=z2, cmap=cmaps[i], norm=mpl.colors.Normalize(vmin=1, vmax=vmax), edgecolor=edgecolors[i], lw=0.2, s=50, alpha=1)
    else:
        scatter = ax.scatter(x2, y2, c=edgecolors[i], edgecolor=edgecolors[i], lw=0.2, s=50, alpha=0.2)
    # scatter = ax.scatter(x2, y2, c=z2, cmap=cmaps[i], edgecolor=edgecolors[i], lw=0.1, s=20)

    # Add colorbar
    if v_type != "below_threshold":
        cbar = fig.colorbar(scatter, ax=ax, pad=0.01, shrink=0.7)
        cbar.ax.yaxis.set_major_locator(MaxNLocator(integer=True))
        if i == 0:
            cbar.ax.tick_params(axis="both", labelsize=fontsize-2)
        else:
            cbar.set_ticks([])
        cbar.ax.set_ylabel(f"# of {labels[i]} viruses", fontsize=fontsize)

# Mark u202260 with black edge
x_ebov = nd(palmdb_adata[palmdb_adata.obs["species"] == "macaca_mulatta", palmdb_adata.var.index=="u202260"].X.sum(axis=0)) / len(palmdb_adata.obs[palmdb_adata.obs["species"] == "macaca_mulatta"])
y_ebov = nd(palmdb_adata[palmdb_adata.obs["species"] == "canis_lupus_familiaris", palmdb_adata.var.index=="u202260"].X.sum(axis=0)) / len(palmdb_adata.obs[palmdb_adata.obs["species"] == "canis_lupus_familiaris"])
ax.scatter(x_ebov*100, y_ebov*100, facecolor=[0, 0, 0, 0], edgecolor=[0, 0, 0, 1], lw=1, s=50)

# # Mark u11842 (trich vaginalis) with black edge
# x_tri = nd(palmdb_adata[palmdb_adata.obs["species"] == "macaca_mulatta", palmdb_adata.var.index=="u11842"].X.sum(axis=0)) / len(palmdb_adata.obs[palmdb_adata.obs["species"] == "macaca_mulatta"])
# y_tri = nd(palmdb_adata[palmdb_adata.obs["species"] == "canis_lupus_familiaris", palmdb_adata.var.index=="u11842"].X.sum(axis=0)) / len(palmdb_adata.obs[palmdb_adata.obs["species"] == "canis_lupus_familiaris"])
# ax.scatter(x_tri*100, y_tri*100, facecolor=[0, 0, 0, 0], edgecolor=[0, 0, 0, 1], lw=1, s=50)

# ax.set_title("Total UMI counts for each virus per cell", fontsize=fontsize+2)
# ax.set_xlabel("Total Macaca mulatta UMI count", fontsize=fontsize)
# ax.set_ylabel("Total MDCK UMI count", fontsize=fontsize)
ax.set_xlabel("Percentage of positive Macaca mulatta cells", fontsize=fontsize)
ax.set_ylabel("Percentage of positive MDCK cells", fontsize=fontsize)

ax.set_xscale("log")
ax.set_yscale("log")

# Add shared threshold area and y=x line
# Get axis limits
lims = [
        np.min([ax.get_xlim(), ax.get_ylim()]),
        np.max([ax.get_xlim(), ax.get_ylim()]),
    ]

# Threshold fold change above/below x=y line
x_thres = np.array(lims)
# ax.plot(x_thres, 10**(np.log10(x_thres)+np.log10(fold_change)), c="grey", lw=1, ls="--")
# ax.plot(x_thres, 10**(np.log10(x_thres)-np.log10(fold_change)), c="grey", lw=1, ls="--")
ax.fill_between(x_thres, 10**(np.log10(x_thres)+np.log10(fold_change)), 10**(np.log10(x_thres)-np.log10(fold_change)), alpha=0.1, color="#f77f00")

# Add minimum fraction threshold lines
ax.plot([min_frac_threshold*100, min_frac_threshold*100], [min_frac_threshold*100, ax.get_xlim()[0]], c="grey", lw=1, ls="--", zorder=-1)
ax.plot([min_frac_threshold*100, ax.get_xlim()[0]], [min_frac_threshold*100, min_frac_threshold*100], c="grey", lw=1, ls="--", zorder=-1)

ax.plot(ax.get_xlim(), ax.get_xlim(), c="grey", lw=1, ls="-")

ax.set_ylim(lims)
ax.set_xlim(lims)
ax.set_aspect("equal")

# Change fontsize of tick labels
ax.tick_params(axis="both", labelsize=fontsize-2)

# ax.grid(True, which="both", color="lightgray", ls="--", lw=1)
# ax.set_axisbelow(True)

# Save figure
fig.savefig(
    "virus_shared_thresholds_bwa.png", dpi=300, bbox_inches="tight", transparent=True
)

fig.show()
# Out:
# 1.0
# 0.0
# 1.0
# 1.0
# 3003.0

# %%
# Zoom into area around 0
fig, ax = plt.subplots(figsize=(12, 10))
fontsize = 14
vmax = 5.0

all_v_types = ["macaca_only", "canis_only", "shared", "undefined", "below_threshold"]
labels = ["macaque only", "MDCK only", "shared", "undefined", "below threshold"]

# Generate colormaps (removing lightest values for visibility)
edgecolors = ["green", "blue", "red", "grey", "lightgrey"]
cmaps_orig = [plt.cm.Greens, plt.cm.Blues, plt.cm.Oranges, plt.cm.Greys]
min_val, max_val = 0.25, 1.0
n = 20
cmaps = []
for orig_cmap in cmaps_orig:
    colors = orig_cmap(np.linspace(min_val, max_val, n))
    cmaps.append(mpl.colors.LinearSegmentedColormap.from_list("mycmap", colors))

for i, v_type in enumerate(all_v_types):
    # # Plot number of canis over macaque UMIs
    # x = (np.array(palmdb_adata[palmdb_adata.obs["species"] == "macaca_mulatta", palmdb_adata.var["v_type"] == v_type].X.sum(axis=0))).flatten()
    # y = (np.array(palmdb_adata[palmdb_adata.obs["species"] == "canis_lupus_familiaris", palmdb_adata.var["v_type"] == v_type].X.sum(axis=0))).flatten()

    # Plot fraction of canis and macaque positive cells
    x = nd(palmdb_adata[palmdb_adata.obs["species"] == "macaca_mulatta", palmdb_adata.var["v_type"] == v_type].X.sum(axis=0)) / len(palmdb_adata.obs[palmdb_adata.obs["species"] == "macaca_mulatta"])
    y = nd(palmdb_adata[palmdb_adata.obs["species"] == "canis_lupus_familiaris", palmdb_adata.var["v_type"] == v_type].X.sum(axis=0)) / len(palmdb_adata.obs[palmdb_adata.obs["species"] == "canis_lupus_familiaris"])

    # Convert to percentages
    x = x*100
    y = y*100

    # Histogram data to show point density
    bins = [1500, 1500]
    hh, locx, locy = np.histogram2d(x, y, bins=bins)
    z = np.array([hh[np.argmax(a<=locx[1:]),np.argmax(b<=locy[1:])] for a,b in zip(x,y)])
    idx = z.argsort()
    x2, y2, z2 = x[idx], y[idx], z[idx]

    print(z2.max())

    # Normalize colormaps to same range
    if v_type != "below_threshold":
        scatter = ax.scatter(x2, y2, c=z2, cmap=cmaps[i], norm=mpl.colors.Normalize(vmin=1, vmax=vmax), edgecolor=edgecolors[i], lw=0.2, s=50, alpha=1)
    else:
        scatter = ax.scatter(x2, y2, c=edgecolors[i], edgecolor=edgecolors[i], lw=0.2, s=50, alpha=0.2)
    # scatter = ax.scatter(x2, y2, c=z2, cmap=cmaps[i], edgecolor=edgecolors[i], lw=0.1, s=20)

    # Add colorbar
    if v_type != "below_threshold":
        cbar = fig.colorbar(scatter, ax=ax, pad=0.01, shrink=0.7)
        cbar.ax.yaxis.set_major_locator(MaxNLocator(integer=True))
        if i == 0:
            cbar.ax.tick_params(axis="both", labelsize=fontsize-2)
        else:
            cbar.set_ticks([])
        cbar.ax.set_ylabel(f"# of {labels[i]} viruses", fontsize=fontsize)

# Mark Ebolavirus with black edge
x_ebov = (np.array(palmdb_adata[palmdb_adata.obs["species"] == "macaca_mulatta", palmdb_adata.var.index=="u10"].X.sum(axis=0))).flatten() / len(palmdb_adata.obs[palmdb_adata.obs["species"] == "macaca_mulatta"])
y_ebov = (np.array(palmdb_adata[palmdb_adata.obs["species"] == "canis_lupus_familiaris", palmdb_adata.var.index=="u10"].X.sum(axis=0))).flatten() / len(palmdb_adata.obs[palmdb_adata.obs["species"] == "canis_lupus_familiaris"])
ax.scatter(x_ebov*100, y_ebov*100, facecolor=[0, 0, 0, 0], edgecolor=[0, 0, 0, 1], lw=1, s=50)

# # Mark influenza with black edge
# x_inf = (np.array(palmdb_adata[palmdb_adata.obs["species"] == "macaca_mulatta", palmdb_adata.var.index=="u1001"].X.sum(axis=0))).flatten() / len(palmdb_adata.obs[palmdb_adata.obs["species"] == "macaca_mulatta"])
# y_inf = (np.array(palmdb_adata[palmdb_adata.obs["species"] == "canis_lupus_familiaris", palmdb_adata.var.index=="u1001"].X.sum(axis=0))).flatten() / len(palmdb_adata.obs[palmdb_adata.obs["species"] == "canis_lupus_familiaris"])
# ax.scatter(x_inf*100, y_inf*100, facecolor=[0, 0, 0, 0], edgecolor=[0, 0, 0, 1], lw=1, s=50)

# ax.set_title("Total UMI counts for each virus per cell", fontsize=fontsize+2)
# ax.set_xlabel("Total Macaca mulatta UMI count", fontsize=fontsize)
# ax.set_ylabel("Total MDCK UMI count", fontsize=fontsize)
ax.set_xlabel("Percentage of positive Macaca mulatta cells", fontsize=fontsize)
ax.set_ylabel("Percentage of positive MDCK cells", fontsize=fontsize)

# Show 0 values
# ax.set_xscale("symlog")
# ax.set_yscale("symlog")

ax.set_ylim(bottom=-0.01, top=0.23)
ax.set_xlim(left=-0.01, right=0.23)

# Add shared threshold area and y=x line
# Get axis limits
lims = [
        0.0001,
        np.max([ax.get_xlim(), ax.get_ylim()]),
    ]

# Threshold fold change above/below x=y line
x_thres = np.array(lims)
# ax.plot(x_thres, 10**(np.log10(x_thres)+np.log10(fold_change)), c="grey", lw=1, ls="--")
# ax.plot(x_thres, 10**(np.log10(x_thres)-np.log10(fold_change)), c="grey", lw=1, ls="--")
ax.fill_between(x_thres, 10**(np.log10(x_thres)+np.log10(fold_change)), 10**(np.log10(x_thres)-np.log10(fold_change)), alpha=0.1, color="#f77f00")

# Add minimum fraction threshold lines
ax.plot([min_frac_threshold*100, min_frac_threshold*100], [min_frac_threshold*100, -1], c="grey", lw=1, ls="--", zorder=-1)
ax.plot([min_frac_threshold*100, -1], [min_frac_threshold*100, min_frac_threshold*100], c="grey", lw=1, ls="--", zorder=-1)

ax.plot(ax.get_xlim(), ax.get_xlim(), c="grey", lw=1, ls="-")

ax.set_aspect("equal")

# Change fontsize of tick labels
ax.tick_params(axis="both", labelsize=fontsize-2)

# ax.grid(True, which="both", color="lightgray", ls="--", lw=1)
# ax.set_axisbelow(True)

# Save figure
fig.savefig(
    "virus_shared_thresholds_zero_bwa.png", dpi=300, bbox_inches="tight", transparent=True
)

fig.show()
# Out:
# 1.0
# 0.0
# 1.0
# 1.0
# 3003.0

# %% [markdown]
# # Plot count histogram to show low counts per virus ID (compared to host) before binarizing:

# %%
palmdb_adata_temp = palmdb_adata.raw[palmdb_adata.obs["celltype"].notnull(), palmdb_adata.var["v_type"] == "macaca_only"].X
vir_counts = nd(palmdb_adata_temp[palmdb_adata_temp>0])

palmdb_adata_temp = palmdb_adata.raw[palmdb_adata.obs["celltype"].notnull(), palmdb_adata.var["v_type"] == "shared"].X
vir_counts2 = nd(palmdb_adata_temp[palmdb_adata_temp>0])

host_counts = nd(mac_adata.raw.X[mac_adata.raw.X>0])

# %%
fig, ax = plt.subplots(figsize=(10, 5))
fontsize = 14

ax.hist(host_counts, bins=160, histtype='stepfilled', edgecolor="grey", facecolor="lightgrey", label="Macaque genes", log=True)
ax.hist(vir_counts2, bins=10, histtype='stepfilled', edgecolor="#f77f00", facecolor="#f77f00", alpha=0.8, label="Viruses (shared)", log=True)
ax.hist(vir_counts, bins=2, histtype='stepfilled', edgecolor="#0f7c49", facecolor="#0f7c49", alpha=1, label="Viruses (macaque only)", log=True)

ax.legend(fontsize=fontsize)

ax.set_xlabel("Count in one cell", fontsize=fontsize)
ax.set_ylabel("Frequency", fontsize=fontsize)

# Change fontsize of tick labels
ax.tick_params(axis="both", labelsize=fontsize-2)

ax.grid(True, which="both", color="lightgray", ls="--", lw=1)
ax.set_axisbelow(True)

plt.savefig("count_histogram_bwa.png", dpi=300, bbox_inches="tight")

fig.show()

# %% [markdown]
# ___

# %%
# Save new binarized virus matrix including host species information and virus types
palmdb_adata.write("virus_bwa.h5ad")
