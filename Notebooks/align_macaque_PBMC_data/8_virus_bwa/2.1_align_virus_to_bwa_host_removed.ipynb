# %%
bp = "PRJNA665227"
fastq_folder = f"/home/laura/projects/virus-watch-data/{bp}/bwa/raw"

# %%
virus_fasta = "/home/laura/projects/virus-watch-data/virus_ref/uniques_noduplicates.fa"
virus_index = "/home/laura/projects/virus-watch-data/virus_ref/kallisto_aa/noduplicates.idx"
virus_t2g = "/home/laura/projects/virus-watch-data/virus_ref/nodup_clu_t2g.txt"

out_folder = f"/home/laura/projects/virus-watch-data/{bp}/full_index_bwa"
host_out_folder = f"/home/laura/projects/virus-watch-data/{bp}/full_index_stringent_dlist_flank1/host_canine"

kallisto = "/home/laura/projects/kallisto/build/src/kallisto"
bustools = "/home/laura/projects/bustools/build/src/bustools"

# %% [markdown]
# Create new batch file with paths to files where host reads were removed based on bwa alignment:

# %%
sample_batch_file = f"{fastq_folder}/batch.txt"

# %%
import os
import glob

# %%
fastqs = []
for filename in glob.glob(f"{fastq_folder}/*.fastq"):
    fastqs.append(filename.split("/")[-1])
    
fastqs.sort()

# %%
len(fastqs)
# Out:
# 212

# %%
samples = []
for fastq in fastqs:
    samples.append(fastq.split("_")[0])

# %%
samples = list(set(samples))
len(samples)
# Out:
# 106

# %%
with open(sample_batch_file, "w") as batch_file:
    for sample in samples:
        fastq1 = sample + "_1.fastq"
        fastq2 = sample + "_2.fastq"
        batch_file.write(sample + "\t" + fastq_folder + "/" + fastq1 + "\t" + fastq_folder + "/" + fastq2 + "\n")

# %% [markdown]
# Generate virus reference index without dlist:

# %%
# !/usr/bin/time -v $kallisto index \
    -t 30 \
    --aa \
    -i $virus_index \
    $virus_fasta
# Out:
# [index] WARNING --d-list-overhang set to < 3; should be >= 3 with --aa
# [build] loading fasta file /home/laura/projects/virus-watch-data/virus_ref/uniques_noduplicates.fa
# [build] k-mer length: 31
# KmerStream::KmerStream(): Start computing k-mer cardinality estimations (1/2)
# KmerStream::KmerStream(): Start computing k-mer cardinality estimations (1/2)
# KmerStream::KmerStream(): Finished
# CompactedDBG::build(): Estimated number of k-mers occurring at least once: 37641510
# CompactedDBG::build(): Estimated number of minimizer occurring at least once: 7877811
# CompactedDBG::filter(): Processed 87630084 k-mers in 296561 reads
# CompactedDBG::filter(): Found 37508917 unique k-mers
# CompactedDBG::filter(): Number of blocks in Bloom filter is 257317
# CompactedDBG::construct(): Extract approximate unitigs (1/2)
# CompactedDBG::construct(): Extract approximate unitigs (2/2)
# CompactedDBG::construct(): Closed all input files
#
# CompactedDBG::construct(): Splitting unitigs (1/2)
#
# CompactedDBG::construct(): Splitting unitigs (2/2)
# CompactedDBG::construct(): Before split: 2040432 unitigs
# CompactedDBG::construct(): After split (1/1): 2040432 unitigs
# CompactedDBG::construct(): Unitigs split: 1631
# CompactedDBG::construct(): Unitigs deleted: 0
#
# CompactedDBG::construct(): Joining unitigs
# CompactedDBG::construct(): After join: 2021701 unitigs
# CompactedDBG::construct(): Joined 19096 unitigs
# [build] building MPHF
# [build] creating equivalence classes ...
# [build] target de Bruijn graph has k-mer length 31 and minimizer length 23
# [build] target de Bruijn graph has 2021701 contigs and contains 37541756 k-mers
#
# 	Command being timed: "/home/laura/projects/kallisto/build/src/kallisto index -t 30 --aa -i /home/laura/projects/virus-watch-data/virus_ref/kallisto_aa/noduplicates.idx /home/laura/projects/virus-watch-data/virus_ref/uniques_noduplicates.fa"
# 	User time (seconds): 877.36
# 	System time (seconds): 9.82
# 	Percent of CPU this job got: 905%
# 	Elapsed (wall clock) time (h:mm:ss or m:ss): 1:38.02
# 	Average shared text size (kbytes): 0
# 	Average unshared data size (kbytes): 0
# 	Average stack size (kbytes): 0
# 	Average total size (kbytes): 0
# 	Maximum resident set size (kbytes): 4393832
# 	Average resident set size (kbytes): 0
# 	Major (requiring I/O) page faults: 1
# 	Minor (reclaiming a frame) page faults: 2775483
# 	Voluntary context switches: 102641
# 	Involuntary context switches: 1545
# 	Swaps: 0
# 	File system inputs: 72816
# 	File system outputs: 1407400
# 	Socket messages sent: 0
# 	Socket messages received: 0
# 	Signals delivered: 0
# 	Page size (bytes): 4096
# 	Exit status: 0

# %% [markdown]
# Align files and correct barcodes based on host whitelist:

# %%
# !/usr/bin/time -v $kallisto bus \
        -i $virus_index \
        -o $out_folder \
        --aa \
        -t 30 \
        -B $sample_batch_file \
        --batch-barcodes \
        -x 0,0,12:0,12,20:1,0,0
# Out:
# [bus] will try running read files supplied in batch file
# [bus] Note: Strand option was not specified; setting it to --unstranded for specified technology
# [index] k-mer length: 31
# [index] number of targets: 296,561
# [index] number of k-mers: 37,541,756
# [quant] running in single-end mode
# [quant] will process file 1: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698573_1.fastq
# [quant] will process file 2: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698573_2.fastq
# [quant] will process file 1: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698501_1.fastq
# [quant] will process file 2: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698501_2.fastq
# [quant] will process file 1: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698523_1.fastq
# [quant] will process file 2: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698523_2.fastq
# [quant] will process file 1: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698521_1.fastq
# [quant] will process file 2: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698521_2.fastq
# [quant] will process file 1: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698566_1.fastq
# [quant] will process file 2: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698566_2.fastq
# [quant] will process file 1: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698519_1.fastq
# [quant] will process file 2: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698519_2.fastq
# [quant] will process file 1: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698529_1.fastq
# [quant] will process file 2: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698529_2.fastq
# [quant] will process file 1: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698533_1.fastq
# [quant] will process file 2: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698533_2.fastq
# [quant] will process file 1: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698568_1.fastq
# [quant] will process file 2: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698568_2.fastq
# [quant] will process file 1: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698539_1.fastq
# [quant] will process file 2: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698539_2.fastq
# [quant] will process file 1: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698574_1.fastq
# [quant] will process file 2: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698574_2.fastq
# [quant] will process file 1: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698506_1.fastq
# [quant] will process file 2: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698506_2.fastq
# [quant] will process file 1: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698514_1.fastq
# [quant] will process file 2: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698514_2.fastq
# [quant] will process file 1: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698512_1.fastq
# [quant] will process file 2: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698512_2.fastq
# [quant] will process file 1: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698510_1.fastq
# [quant] will process file 2: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698510_2.fastq
# [quant] will process file 1: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698538_1.fastq
# [quant] will process file 2: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698538_2.fastq
# [quant] will process file 1: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698579_1.fastq
# [quant] will process file 2: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698579_2.fastq
# [quant] will process file 1: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698545_1.fastq
# [quant] will process file 2: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698545_2.fastq
# [quant] will process file 1: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698554_1.fastq
# [quant] will process file 2: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698554_2.fastq
# [quant] will process file 1: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698580_1.fastq
# [quant] will process file 2: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698580_2.fastq
# [quant] will process file 1: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698560_1.fastq
# [quant] will process file 2: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698560_2.fastq
# [quant] will process file 1: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698571_1.fastq
# [quant] will process file 2: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12
/home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698530_2.fastq
# [quant] will process file 1: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698588_1.fastq
# [quant] will process file 2: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698588_2.fastq
# [quant] will process file 1: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698534_1.fastq
# [quant] will process file 2: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698534_2.fastq
# [quant] will process file 1: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698509_1.fastq
# [quant] will process file 2: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698509_2.fastq
# [quant] will process file 1: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698557_1.fastq
# [quant] will process file 2: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698557_2.fastq
# [quant] will process file 1: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698597_1.fastq
# [quant] will process file 2: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698597_2.fastq
# [quant] will process file 1: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698516_1.fastq
# [quant] will process file 2: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698516_2.fastq
# [quant] will process file 1: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698540_1.fastq
# [quant] will process file 2: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698540_2.fastq
# [quant] will process file 1: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698520_1.fastq
# [quant] will process file 2: /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/SRR12698520_2.fastq
# [progress] 2339M reads processed (10.0% mapped)             .4% mapped)             11.6% mapped)             11.0% mapped)             10.7% mapped)             10.5% mapped)             10.5% mapped)             11.0% mapped)              done
# [quant] processed 2,340,332,547 reads, 234,424,610 reads pseudoaligned
#
# 	Command being timed: "/home/laura/projects/kallisto/build/src/kallisto bus -i /home/laura/projects/virus-watch-data/virus_ref/kallisto_aa/noduplicates.idx -o /home/laura/projects/virus-watch-data/PRJNA665227/full_index_bwa --aa -t 30 -B /home/laura/projects/virus-watch-data/PRJNA665227/bwa/raw/batch.txt --batch-barcodes -x 0,0,12:0,12,20:1,0,0"
# 	User time (seconds): 269373.52
# 	System time (seconds): 730.34
# 	Percent of CPU this job got: 2985%
# 	Elapsed (wall clock) time (h:mm:ss or m:ss): 2:30:46
# 	Average shared text size (kbytes): 0
# 	Average unshared data size (kbytes): 0
# 	Average stack size (kbytes): 0
# 	Average total size (kbytes): 0
# 	Maximum resident set size (kbytes): 1553440
# 	Average resident set size (kbytes): 0
# 	Major (requiring I/O) page faults: 3
# 	Minor (reclaiming a frame) page faults: 69556021
# 	Voluntary context switches: 458966
# 	Involuntary context switches: 823074
# 	Swaps: 0
# 	File system inputs: 1308775944
# 	File system outputs: 14873720
# 	Socket messages sent: 0
# 	Socket messages received: 0
# 	Signals delivered: 0
# 	Page size (bytes): 4096
# 	Exit status: 0

# %%
# %%time
# !$bustools sort \
    -m 4G \
    -t 20 \
    -o $out_folder/output_sorted.bus \
    $out_folder/output.bus

# !$bustools correct \
    -w $host_out_folder/bustools_whitelist.txt \
    -o $out_folder/output_sorted_corrected.bus \
    $out_folder/output_sorted.bus

# !$bustools sort \
    -m 4G \
    -t 30 \
    -o $out_folder/output_sorted_corrected_sorted.bus \
    $out_folder/output_sorted_corrected.bus

# !$bustools count \
    --genecounts \
    -o $out_folder/bustools_count/ \
    -g $virus_t2g \
    -e $out_folder/matrix.ec \
    -t $out_folder/transcripts.txt \
    $out_folder/output_sorted_corrected_sorted.bus
# Out:
# partition time: 3.74s
# partition time: 2.21s
# Read in 234424610 BUS records
# reading time 4.44s
# sorting time 49.3s
# writing time 0s
# Found 775516 barcodes in the on-list
# Processed 65542131 BUS records
# In on-list = 13464785
# Corrected    = 15472040
# Uncorrected  = 36605306
# partition time: 0.48s
#  all fits in buffer
# Read in 28936825 BUS records
# reading time 0.41s
# sorting time 5.57s
# writing time 0.85s
# CPU times: user 1.85 s, sys: 378 ms, total: 2.23 s
# Wall time: 1min 53s
